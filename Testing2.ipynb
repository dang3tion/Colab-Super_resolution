# %%
from google.colab import drive
drive.mount('/content/drive')
! pwd
# %cd drive/MyDrive
# Out:
# Mounted at /content/drive
# /content
# /content/drive/MyDrive

# %%
# %cd Colab-Super_resolution/
# !git status

# %%
# !git add .

# %%
! git config --global user.email "huudang161019@gmail.com"
! git config --global user.name "dang3tion"

# %%
! git commit -a -m 'editing .py note'
! git push -u origin main
# Out:
# [main ad9ae18] editing .py note
#  1 file changed, 1 insertion(+)
#  create mode 100644 Testing2.ipynb
# Counting objects: 3, done.
# Delta compression using up to 2 threads.
# Compressing objects: 100% (3/3), done.
# Writing objects: 100% (3/3), 1.44 KiB | 737.00 KiB/s, done.
# Total 3 (delta 1), reused 0 (delta 0)
# remote: Resolving deltas: 100% (1/1), completed with 1 local object.
# To https://github.com/dang3tion/Colab-Super_resolution.git
#    4e2fc3a..ad9ae18  main -> main
# Branch 'main' set up to track remote branch 'main' from 'origin'.

# %%
# !git pull
# Out:
# Already up to date.
