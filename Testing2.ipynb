# %%
from google.colab import drive
drive.mount('/content/drive')
! pwd
# %cd drive/MyDrive
# Out:
# Mounted at /content/drive
# /content
# /content/drive/MyDrive

# %%
# %cd Colab-Super_resolution/
# !git status

# %%
# !git add .

# %%
! git config --global user.email "huudang161019@gmail.com"
! git config --global user.name "dang3tion"

# %%
! git commit -a -m 'editing .py note'
! git push -u origin main
# Out:
# [main d02311f] editing .py note
#  1 file changed, 1 insertion(+), 1 deletion(-)
#  rewrite Testing2.ipynb (68%)
# Counting objects: 3, done.
# Delta compression using up to 2 threads.
# Compressing objects: 100% (3/3), done.
# Writing objects: 100% (3/3), 583 bytes | 583.00 KiB/s, done.
# Total 3 (delta 2), reused 0 (delta 0)
# remote: Resolving deltas: 100% (2/2), completed with 2 local objects.
# To https://github.com/dang3tion/Colab-Super_resolution.git
#    ad9ae18..d02311f  main -> main
# Branch 'main' set up to track remote branch 'main' from 'origin'.

# %%
# !git pull
# Out:
# Already up to date.

# %%
print('asdfa')
# Out:
# asdfa
